# %% [markdown]
# # Reflection and Blogpost Writing

# %% [markdown]
# ## Setup

# %%
from utils import get_openai_api_key
OPENAI_API_KEY = get_openai_api_key()
#print(OPENAI_API_KEY)
llm_config = {"model": "llama3","api_type":"ollama"}
#llm_config = {"model": "gemini-2.5-flash","api_key":"","api_type":"google"}

# %% [markdown]
# The task!

# %%
task = '''
        Write a concise but engaging blogpost about
      Mugil soft solutions . Make sure the blogpost is
       within 100 words.
       '''

# %% [markdown]
# Create a writer agent

# %%
import autogen

writer = autogen.AssistantAgent(
    name="Writer",
    system_message="You are a writer. You write engaging and concise " 
        "blogpost (with title) on given topics. You must polish your "
        "writing based on the feedback you receive and give a refined "
        "version. Only return your final work without additional comments.",
    llm_config=llm_config,
)
# Out:
# C:\Users\Manikandan\anaconda3\envs\mygpu\lib\site-packages\google\api_core\_python_version_support.py:273: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.cloud.resourcemanager_v3 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.resourcemanager_v3 past that date.
#   warnings.warn(message, FutureWarning)
# Patching name='__init__', member=<function LLMLingua.__init__ at 0x00000169B0C0B130>, patched=<function function.__call__ at 0x00000169B0C0AF80>
# Patching name='compress_text', member=<function LLMLingua.compress_text at 0x00000169B0C0B1C0>, patched=<function function.__call__ at 0x00000169B0C0B370>

# %%
reply = writer.generate_reply(messages=[{"content": task,"role": "user"}])
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 reply = writer.generate_reply(messages=[{"content": task,"role": "user"}])
#
# File ~\anaconda3\envs\mygpu\lib\site-packages\autogen\agentchat\conversable_agent.py:2066, in ConversableAgent.generate_reply(self, messages, sender, **kwargs)
#    2064     continue
#    2065 if self._match_trigger(reply_func_tuple["trigger"], sender):
# -> 2066     final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#    2067     if logging_enabled():
#    2068         log_event(
#    2069             self,
#    2070             "reply_func_executed",
#    (...)
#    2074             reply=reply,
#    2075         )
#
# File ~\anaconda3\envs\mygpu\lib\site-packages\autogen\agentchat\conversable_agent.py:1443, in ConversableAgent.generate_oai_reply(self, messages, sender, config)
#    1441 if messages is None:
#    1442     messages = self._oai_messages[sender]
# -> 1443 extracted_response = self._generate_oai_reply_from_client(
#    1444     client, self._oai_system_message + messages, self.client_cache
#    1445 )
#    1446 return (False, None) if extracted_response is None else (True, extracted_response)
#
# File ~\anaconda3\envs\mygpu\lib\site-packages\autogen\agentchat\conversable_agent.py:1462, in ConversableAgent._generate_oai_reply_from_client(self, llm_client, messages, cache)
#    1459         all_messages.append(message)
#    1461 # TODO: #1143 handle token limit exceeded error
# -> 1462 response = llm_client.create(
#    1463     context=messages[-1].pop("context", None),
#    1464     messages=all_messages,
#    1465     cache=cache,
#    1466     agent=self,
#    1467 )
#    1468 extracted_response = llm_client.extract_text_or_completion_object(response)[0]
#    1470 if extracted_response is None:
#
# File ~\anaconda3\envs\mygpu\lib\site-packages\autogen\oai\client.py:964, in OpenAIWrapper.create(self, **config)
#     962 try:
#     963     request_ts = get_current_ts()
# --> 964     response = client.create(params)
#     965 except APITimeoutError as err:
#     966     logger.debug(f"config {i} timed out", exc_info=True)
#
# File ~\anaconda3\envs\mygpu\lib\site-packages\autogen\oai\ollama.py:248, in OllamaClient.create(self, params)
#     246     response = client.chat(**ollama_params)
#     247 else:
# --> 248     response = ollama.chat(**ollama_params)
#     250 if ollama_params["stream"]:
#     251     # Read in the chunks as they stream, taking in tool_calls which may be across
#     252     # multiple chunks if more than one suggested
#     253     ans = ""
#
# File ~\anaconda3\envs\mygpu\lib\site-packages\ollama\_client.py:365, in Client.chat(self, model, messages, tools, stream, think, logprobs, top_logprobs, format, options, keep_alive)
#     318 def chat(
#     319   self,
#     320   model: str = '',
#    (...)
#     330   keep_alive: Optional[Union[float, str]] = None,
#     331 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     332   """
#     333   Create a chat response using the requested model.
#     334
#    (...)
#     363   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     364   """
# --> 365   return self._request(
#     366     ChatResponse,
#     367     'POST',
#     368     '/api/chat',
#     369     json=ChatRequest(
#     370       model=model,
#     371       messages=list(_copy_messages(messages)),
#     372       tools=list(_copy_tools(tools)),
#     373       stream=stream,
#     374       think=think,
#     375       logprobs=logprobs,
#     376       top_logprobs=top_logprobs,
#     377       format=format,
#     378       options=options,
#     379       keep_alive=keep_alive,
#     380     ).model_dump(exclude_none=True),
#     381     stream=stream,
#     382   )
#
# File ~\anaconda3\envs\mygpu\lib\site-packages\ollama\_client.py:189, in Client._request(self, cls, stream, *args, **kwargs)
#     185         yield cls(**part)
#     187   return inner()
# --> 189 return cls(**self._request_raw(*args, **kwargs).json())
#
# File ~\anaconda3\envs\mygpu\lib\site-packages\ollama\_client.py:133, in Client._request_raw(self, *args, **kwargs)
#     131   return r
#     132 except httpx.HTTPStatusError as e:
# --> 133   raise ResponseError(e.response.text, e.response.status_code) from None
#     134 except httpx.ConnectError:
#     135   raise ConnectionError(CONNECTION_ERROR_MESSAGE) from None
#
# ResponseError: model 'llama3' not found (status code: 404)

# %%
print(reply)
# Out:
# {'content': '## Unlock Your Digital Potential with Mugil Soft Solutions\n\nStruggling to navigate the complex digital landscape? Mugil Soft Solutions is your trusted partner. We craft innovative software and provide expert IT services designed to streamline your operations and boost your growth. From custom applications to robust cloud solutions, our dedicated team delivers precision and reliability. Experience the difference of seamless technology – transform your business today with Mugil Soft Solutions!', 'refusal': None, 'role': 'assistant', 'annotations': None, 'audio': None, 'function_call': None, 'tool_calls': None}

# %% [markdown]
# ## Adding reflection
#
# Create a critic agent to reflect on the work of the writer agent.

# %%
critic = autogen.AssistantAgent(
    name="Critic",
    is_termination_msg=lambda x: x.get("content", "").find("TERMINATE") >= 0,
    llm_config=llm_config,
    system_message="You are a critic. You review the work of "
                "the writer and provide constructive "
                "feedback to help improve the quality of the content.",
)

# %%
res = critic.initiate_chat(
    recipient=writer,
    message=task,
    max_turns=2,
    summary_method="last_msg"
)
# Out:
# Critic (to Writer):
#
#
#         Write a concise but engaging blogpost about
#       Mugil soft solutions . Make sure the blogpost is
#        within 100 words.
#
#
# --------------------------------------------------------------------------------
# Writer (to Critic):
#
# ## Mugil Soft Solutions: Your Digital Edge
#
# Facing tech hurdles? Mugil Soft Solutions delivers innovative answers. We craft bespoke software – from intuitive web apps to robust enterprise systems – tailored to your unique business challenges. Our focus: seamless integration, scalable performance, and user-centric design. We build more than software; we create powerful solutions that empower growth, streamline operations, and transform your vision into reality. Partner with us. Discover the tailored technology that drives success.
#
# --------------------------------------------------------------------------------
# Critic (to Writer):
#
# Okay, let's put on the critic's hat and dive into "Mugil Soft Solutions: Your Digital Edge."
#
# ***
#
# ## Critique: Mugil Soft Solutions Blog Post
#
# This is a well-structured, concise piece that effectively communicates Mugil Soft Solutions' core offering within the strict word count. It gets straight to the point and addresses the pain points of potential clients.
#
# **Strengths:**
#
# 1.  **Punchy Title & Hook:** "Your Digital Edge" is strong, and "Facing tech hurdles?" immediately draws the reader in by posing a relatable problem.
# 2.  **Clear Value Proposition:** The post clearly states what Mugil Soft Solutions does (crafts bespoke software) and the range of services (web apps to enterprise systems).
# 3.  **Benefit-Oriented Language:** It effectively highlights the *outcomes* for clients – seamless integration, scalable performance, empowered growth, streamlined operations, and vision transformation – rather than just listing features.
# 4.  **Strong Call to Action:** "Partner with us. Discover the tailored technology that drives success" is direct and encouraging.
# 5.  **Conciseness:** You've nailed the "within 100 words" requirement, making it digestible and impactful for a blog post.
#
# **Areas for Refinement (Constructive Feedback):**
#
# 1.  **Vocabulary Variety – The "Solutions" Repetition:** While your company name includes "Solutions," the word appears several times throughout the post ("innovative answers," "powerful solutions," "Mugil Soft Solutions").
#     *   **Suggestion:** Consider varying the vocabulary slightly. For example, instead of "delivers innovative answers," perhaps "unearths digital breakthroughs" or "engineers cutting-edge innovations." This can prevent a slight redundancy and make the prose feel fresher.
#
# 2.  **Strengthening Differentiation:** You mention "bespoke software" and tailoring to "unique business challenges," which is excellent. However, many software companies claim this.
#     *   **Suggestion:** Can you weave in a *hint* of *how* Mugil approaches this tailoring or what makes their methodology unique, even in a micro-phrase? For instance, after "user-centric design," you could briefly add "...ensuring every line of code aligns with *your* strategic vision" or "...driven by a deep understanding of *your* industry." This adds a subtle layer of unique identity without sacrificing conciseness.
#
# 3.  **Active Voice and Impact:** The phrase "Our focus: seamless integration..." is good, but could be slightly more active.
#     *   **Suggestion:** Consider something like "We *champion* seamless integration, scalable performance, and intuitive design" or "Our expertise *revolves around* seamless integration..." This adds a bit more dynamism to an already strong statement.
#
# **Overall:**
#
# This is a very solid piece of writing that does its job effectively. The feedback points are minor tweaks aimed at elevating an already good blog post to an even more compelling one. You've clearly articulated Mugil's value. A little linguistic polish can make it truly shine!
#
# --------------------------------------------------------------------------------
# Writer (to Critic):
#
# ## Mugil Soft Solutions: Your Digital Edge
#
# Facing tech hurdles? Mugil Soft Solutions engineers cutting-edge innovations. We craft bespoke software – from intuitive web apps to robust enterprise systems – tailored to your unique business challenges, meticulously aligned with your strategic goals. We champion seamless integration, scalable performance, and user-centric design. We build more than software; we forge pathways to growth, streamline operations, and transform your vision into reality. Partner with us. Discover the tailored technology that drives success.
#
# --------------------------------------------------------------------------------

# %%
SEO_reviewer = autogen.AssistantAgent(
    name="SEO_Reviewer",
    llm_config=llm_config,
    system_message="You are an SEO reviewer, known for "
        "your ability to optimize content for search engines, "
        "ensuring that it ranks well and attracts organic traffic. " 
        "Make sure your suggestion is concise (within 3 bullet points), "
        "concrete and to the point. "
        "Begin the review by stating your role.",
)

# %%
legal_reviewer = autogen.AssistantAgent(
    name="Legal_Reviewer",
    llm_config=llm_config,
    system_message="You are a legal reviewer, known for "
        "your ability to ensure that content is legally compliant "
        "and free from any potential legal issues. "
        "Make sure your suggestion is concise (within 3 bullet points), "
        "concrete and to the point. "
        "Begin the review by stating your role.",
)

# %%
ethics_reviewer = autogen.AssistantAgent(
    name="Ethics_Reviewer",
    llm_config=llm_config,
    system_message="You are an ethics reviewer, known for "
        "your ability to ensure that content is ethically sound "
        "and free from any potential ethical issues. " 
        "Make sure your suggestion is concise (within 3 bullet points), "
        "concrete and to the point. "
        "Begin the review by stating your role. ",
)

# %%
meta_reviewer = autogen.AssistantAgent(
    name="Meta_Reviewer",
    llm_config=llm_config,
    system_message="You are a meta reviewer, you aggragate and review "
    "the work of other reviewers and give a final suggestion on the content.",
)

# %% [markdown]
# ## Orchestrate the nested chats to solve the task

# %%
def reflection_message(recipient, messages, sender, config):
    return f'''Review the following content. 
            \n\n {recipient.chat_messages_for_summary(sender)[-1]['content']}'''

review_chats = [
    {
     "recipient": SEO_reviewer, 
     "message": reflection_message, 
     "summary_method": "reflection_with_llm",
     "summary_args": {"summary_prompt" : 
        "Return review into as JSON object only:"
        "{'Reviewer': '', 'Review': ''}. Here Reviewer should be your role",},
     "max_turns": 1},
    {
    "recipient": legal_reviewer, "message": reflection_message, 
     "summary_method": "reflection_with_llm",
     "summary_args": {"summary_prompt" : 
        "Return review into as JSON object only:"
        "{'Reviewer': '', 'Review': ''}.",},
     "max_turns": 1},
    {"recipient": ethics_reviewer, "message": reflection_message, 
     "summary_method": "reflection_with_llm",
     "summary_args": {"summary_prompt" : 
        "Return review into as JSON object only:"
        "{'reviewer': '', 'review': ''}",},
     "max_turns": 1},
     {"recipient": meta_reviewer, 
      "message": "Aggregrate feedback from all reviewers and give final suggestions on the writing.", 
     "max_turns": 1},
]

# %%
critic.register_nested_chats(
    review_chats,
    trigger=writer,
)

# %% [markdown]
# **Note**: You might get a slightly different response than what's shown in the video. Feel free to try different task.

# %%
res = critic.initiate_chat(
    recipient=writer,
    message=task,
    max_turns=2,
    summary_method="last_msg"
)
# Out:
# Critic (to Writer):
#
#
#         Write a concise but engaging blogpost about
#       Mugil soft solutions . Make sure the blogpost is
#        within 100 words.
#
#
# --------------------------------------------------------------------------------
# Writer (to Critic):
#
# ## Mugil Soft Solutions: Your Digital Edge
#
# Facing tech hurdles? Mugil Soft Solutions delivers innovative answers. We craft bespoke software – from intuitive web apps to robust enterprise systems – tailored to your unique business challenges. Our focus: seamless integration, scalable performance, and user-centric design. We build more than software; we create powerful solutions that empower growth, streamline operations, and transform your vision into reality. Partner with us. Discover the tailored technology that drives success.
#
# --------------------------------------------------------------------------------
#
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# Critic (to SEO_Reviewer):
#
# Review the following content.
#
#
#  ## Mugil Soft Solutions: Your Digital Edge
#
# Facing tech hurdles? Mugil Soft Solutions delivers innovative answers. We craft bespoke software – from intuitive web apps to robust enterprise systems – tailored to your unique business challenges. Our focus: seamless integration, scalable performance, and user-centric design. We build more than software; we create powerful solutions that empower growth, streamline operations, and transform your vision into reality. Partner with us. Discover the tailored technology that drives success.
#
# --------------------------------------------------------------------------------
# SEO_Reviewer (to Critic):
#
# As an SEO Reviewer focused on optimizing for search engine ranking and organic traffic, here are my suggestions:
#
# *   **Integrate Core Service Keywords:** Explicitly weave in high-volume, direct service keywords such as "custom software development services" or "bespoke software solutions company" early and naturally into the content.
# *   **Strengthen Opening Statement:** Rephrase the initial sentences to clearly state your primary offering (e.g., "Mugil Soft Solutions specializes in custom software development...") to immediately align with search intent.
# *   **Elaborate on Problem/Solution:** Briefly connect your solutions ("seamless integration," "scalable performance") to specific business challenges you solve (e.g., "reducing operational inefficiencies" or "optimizing workflows") for better problem-solution query matching.
#
# --------------------------------------------------------------------------------
#
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# Critic (to Legal_Reviewer):
#
# Review the following content.
#
#
#  ## Mugil Soft Solutions: Your Digital Edge
#
# Facing tech hurdles? Mugil Soft Solutions delivers innovative answers. We craft bespoke software – from intuitive web apps to robust enterprise systems – tailored to your unique business challenges. Our focus: seamless integration, scalable performance, and user-centric design. We build more than software; we create powerful solutions that empower growth, streamline operations, and transform your vision into reality. Partner with us. Discover the tailored technology that drives success.
# Context:
# ```json
# {
#   "Reviewer": "SEO Reviewer",
#   "Review": "To optimize for SEO, integrate high-volume, direct service keywords such as 'custom software development services' or 'bespoke software solutions company' naturally and early in the content. Strengthen the opening statement to explicitly state your primary offering (e.g., 'Mugil Soft Solutions specializes in custom software development...') to immediately align with search intent. Briefly elaborate on the problem/solution by connecting your solutions (e.g., 'seamless integration,' 'scalable performance') to specific business challenges you solve (e.g., 'reducing operational inefficiencies' or 'optimizing workflows') for better problem-solution query matching."
# }
# ```
#
# --------------------------------------------------------------------------------
# Legal_Reviewer (to Critic):
#
# As a Legal Reviewer, my suggestions are:
#
# *   Review claims such as 'empower growth' and 'streamline operations' to ensure they are presented as *potential benefits* or *facilitators* rather than unqualified guarantees, minimizing the risk of misrepresentation.
# *   Verify that all descriptive terms like 'bespoke software' and 'seamless integration' accurately reflect your current service capabilities and can be substantiated if challenged.
#
# --------------------------------------------------------------------------------
#
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# Critic (to Ethics_Reviewer):
#
# Review the following content.
#
#
#  ## Mugil Soft Solutions: Your Digital Edge
#
# Facing tech hurdles? Mugil Soft Solutions delivers innovative answers. We craft bespoke software – from intuitive web apps to robust enterprise systems – tailored to your unique business challenges. Our focus: seamless integration, scalable performance, and user-centric design. We build more than software; we create powerful solutions that empower growth, streamline operations, and transform your vision into reality. Partner with us. Discover the tailored technology that drives success.
# Context:
# ```json
# {
#   "Reviewer": "SEO Reviewer",
#   "Review": "To optimize for SEO, integrate high-volume, direct service keywords such as 'custom software development services' or 'bespoke software solutions company' naturally and early in the content. Strengthen the opening statement to explicitly state your primary offering (e.g., 'Mugil Soft Solutions specializes in custom software development...') to immediately align with search intent. Briefly elaborate on the problem/solution by connecting your solutions (e.g., 'seamless integration,' 'scalable performance') to specific business challenges you solve (e.g., 'reducing operational inefficiencies' or 'optimizing workflows') for better problem-solution query matching."
# }
# ```
# ```json
# {
#   "Reviewer": "Legal Reviewer",
#   "Review": "1. **Substantiation of Claims:** Review all benefit-oriented statements such as 'empower growth,' 'streamline operations,' and 'transform your vision into reality.' Ensure these are presented as potential outcomes or capabilities rather than absolute guarantees. It is crucial to avoid any language that could be interpreted as a firm promise of specific results, which might lead to claims of misrepresentation if those outcomes are not universally achieved for every client. Consider adding qualifying language like 'We help empower growth...' or 'aims to streamline operations...' \n2. **Accuracy of Service Descriptions:** Verify that terms used to describe services and their attributes (e.g., 'bespoke software,' 'intuitive web apps,' 'robust enterprise systems,' 'seamless integration,' 'scalable performance,' 'user-centric design') accurately and truthfully reflect the current capabilities, methodologies, and quality standards of Mugil Soft Solutions. All claims made about the nature and quality of the services should be defensible with evidence if challenged.\n3. **Clarity on Scope:** While the content is high-level, ensure there's no ambiguity that could mislead potential clients about the typical scope or limitations of the services offered, especially for 'bespoke' solutions which inherently vary."
# }
# ```
#
# --------------------------------------------------------------------------------
# Ethics_Reviewer (to Critic):
#
# As an Ethics Reviewer, I ensure content is ethically sound and free from potential issues, focusing on transparency, honesty, and responsible communication.
#
# *   **Prioritize Transparency and Realistic Expectations:** Reframe strong benefit claims (e.g., "empower growth," "transform your vision into reality") with qualifying language (e.g., "we help clients to empower growth") to indicate potential outcomes rather than absolute guarantees, fostering honest communication and setting appropriate client expectations.
# *   **Uphold Factual Integrity:** Confirm that all descriptions of service capabilities and attributes (e.g., "innovative answers," "seamless integration," "user-centric design") are rigorously accurate and truly reflective of Mugil Soft Solutions' current expertise and offerings, avoiding any potential for misrepresentation.
# *   **Ensure Clarity on Bespoke Solutions:** Given the emphasis on "bespoke software" and "tailored solutions," ensure there's no ambiguity that could mislead potential clients about typical project scopes, variable costs, or the client involvement generally required for such custom services.
#
# --------------------------------------------------------------------------------
#
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# Critic (to Meta_Reviewer):
#
# Aggregrate feedback from all reviewers and give final suggestions on the writing.
# Context:
# ```json
# {
#   "Reviewer": "SEO Reviewer",
#   "Review": "To optimize for SEO, integrate high-volume, direct service keywords such as 'custom software development services' or 'bespoke software solutions company' naturally and early in the content. Strengthen the opening statement to explicitly state your primary offering (e.g., 'Mugil Soft Solutions specializes in custom software development...') to immediately align with search intent. Briefly elaborate on the problem/solution by connecting your solutions (e.g., 'seamless integration,' 'scalable performance') to specific business challenges you solve (e.g., 'reducing operational inefficiencies' or 'optimizing workflows') for better problem-solution query matching."
# }
# ```
# ```json
# {
#   "Reviewer": "Legal Reviewer",
#   "Review": "1. **Substantiation of Claims:** Review all benefit-oriented statements such as 'empower growth,' 'streamline operations,' and 'transform your vision into reality.' Ensure these are presented as potential outcomes or capabilities rather than absolute guarantees. It is crucial to avoid any language that could be interpreted as a firm promise of specific results, which might lead to claims of misrepresentation if those outcomes are not universally achieved for every client. Consider adding qualifying language like 'We help empower growth...' or 'aims to streamline operations...' \n2. **Accuracy of Service Descriptions:** Verify that terms used to describe services and their attributes (e.g., 'bespoke software,' 'intuitive web apps,' 'robust enterprise systems,' 'seamless integration,' 'scalable performance,' 'user-centric design') accurately and truthfully reflect the current capabilities, methodologies, and quality standards of Mugil Soft Solutions. All claims made about the nature and quality of the services should be defensible with evidence if challenged.\n3. **Clarity on Scope:** While the content is high-level, ensure there's no ambiguity that could mislead potential clients about the typical scope or limitations of the services offered, especially for 'bespoke' solutions which inherently vary."
# }
# ```
# ```json
# {
#   "reviewer": "Ethics Reviewer",
#   "review": "1. **Transparency and Realistic Expectations:** Reframe strong benefit claims (e.g., \"empower growth,\" \"transform your vision into reality\") with qualifying language (e.g., \"we help clients to empower growth,\" \"aim to transform your vision\") to clearly indicate potential outcomes rather than absolute guarantees. This promotes honest communication and sets appropriate client expectations, mitigating the risk of perceived over-promising.\n2. **Factual Integrity of Service Descriptions:** Ensure that all descriptions of service capabilities and attributes (e.g., \"innovative answers,\" \"seamless integration,\" \"user-centric design\") are rigorously accurate and truly reflective of Mugil Soft Solutions' current expertise, methodologies, and offerings. Avoid any language that could potentially misrepresent the actual scope or quality of services.\n3. **Clarity on Bespoke Solutions:** While the content highlights \"bespoke software\" and \"tailored solutions,\" ensure there's no ambiguity that could mislead potential clients regarding the typical project scopes, variable costs, or the level of client involvement generally required for custom services. Transparency here prevents misunderstandings about the nature of personalized solutions."
# }
# ```
#
# --------------------------------------------------------------------------------
# Meta_Reviewer (to Critic):
#
#
#
# --------------------------------------------------------------------------------
# Critic (to Writer):
#
#
#
# --------------------------------------------------------------------------------
# Writer (to Critic):
#
# ## Unlock Your Potential with Mugil Soft Solutions
#
# Is generic software hindering your growth? Mugil Soft Solutions crafts custom digital solutions designed precisely for your business. We build powerful web applications, intuitive mobile experiences, and streamlined enterprise systems that integrate seamlessly. Our focus isn't just code; it's empowering your operations, boosting efficiency, and transforming challenges into opportunities. Partner with us to unleash innovation and drive measurable results. Experience technology that truly works for you.
#
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Get the summary

# %%
print(res.summary)
# Out:
# ## Unlock Your Potential with Mugil Soft Solutions
#
# Is generic software hindering your growth? Mugil Soft Solutions crafts custom digital solutions designed precisely for your business. We build powerful web applications, intuitive mobile experiences, and streamlined enterprise systems that integrate seamlessly. Our focus isn't just code; it's empowering your operations, boosting efficiency, and transforming challenges into opportunities. Partner with us to unleash innovation and drive measurable results. Experience technology that truly works for you.
