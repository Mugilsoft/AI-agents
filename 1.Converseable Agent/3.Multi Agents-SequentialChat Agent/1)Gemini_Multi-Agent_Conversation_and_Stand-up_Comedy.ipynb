# %%
# Multi-Agent Conversation and Stand-up Comedy

# %%
## Setup

# %%
from utils import get_Gemini_api_key
Gemini_API_KEY = get_Gemini_api_key()
print(Gemini_API_KEY)
llm_config = {"model": "gemini-2.5-flash","api_key":"AIzaSyAsGwS-k9nkjG7huXV-9eTeEjfuKu8bnWY","api_type":"google"}
# Out:
# AIzaSyAsGwS-k9nkjG7huXV-9eTeEjfuKu8bnWY

# %%
#!pip install ipywidgets

# %%
from autogen import ConversableAgent

agent = ConversableAgent(
    name="chatbot",
    llm_config=llm_config,
    human_input_mode="NEVER",
)
# Out:
# C:\Users\Manikandan\anaconda3\envs\mygpu\lib\site-packages\google\api_core\_python_version_support.py:273: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# C:\Users\Manikandan\anaconda3\envs\mygpu\lib\site-packages\google\api_core\_python_version_support.py:273: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.cloud.resourcemanager_v3 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.resourcemanager_v3 past that date.
#   warnings.warn(message, FutureWarning)
# Patching name='__init__', member=<function LLMLingua.__init__ at 0x000001FCC2579C60>, patched=<function function.__call__ at 0x000001FCC2579AB0>
# Patching name='compress_text', member=<function LLMLingua.compress_text at 0x000001FCC2579CF0>, patched=<function function.__call__ at 0x000001FCC2579EA0>

# %%
reply = agent.generate_reply(
    messages=[{"content": "Tell me a joke.", "role": "user"}]
)
print(reply)
# Out:
# {'content': "Why don't scientists trust atoms?\n\nBecause they make up everything!", 'refusal': None, 'role': 'assistant', 'annotations': None, 'audio': None, 'function_call': None, 'tool_calls': None}
# C:\Users\Manikandan\anaconda3\envs\mygpu\lib\site-packages\autogen\oai\gemini.py:803: UserWarning: Cost calculation is not implemented for model gemini-2.5-flash. Cost will be calculated zero.
#   warnings.warn(

# %%
reply = agent.generate_reply(
    messages=[{"content": "Repeat the joke.", "role": "user"}]
)
print(reply)
# Out:
# {'content': "Please tell me the joke first! I'll be happy to repeat it for you. 😄", 'refusal': None, 'role': 'assistant', 'annotations': None, 'audio': None, 'function_call': None, 'tool_calls': None}

# %%
## Conversation

#Setting up a conversation between two agents, Cathy and Joe, where the memory of their interactions is retained.

# %%
cathy = ConversableAgent(
    name="cathy",
    system_message=
    "Your name is Cathy and you are a stand-up comedian.",
    llm_config=llm_config,
    human_input_mode="NEVER",
)

joe = ConversableAgent(
    name="joe",
    system_message=
    "Your name is Joe and you are a stand-up comedian. "
    "Start the next joke from the punchline of the previous joke.",
    llm_config=llm_config,
    human_input_mode="NEVER",
)

# %%
chat_result = joe.initiate_chat(
    recipient=cathy, 
    message="I'm Joe. Cathy, let's keep the jokes rolling.",
    max_turns=2,
)
# Out:
# joe (to cathy):
#
# I'm Joe. Cathy, let's keep the jokes rolling.
#
# --------------------------------------------------------------------------------
# cathy (to joe):
#
# Alright, Joe! My man! Good to see you still in the house! You know, I love an audience that keeps demanding more. It tells me you're either having a great time, or your car broke down and you're just really bored. Either way, I'm here for you!
#
# So, I was at the grocery store the other day, right? And I saw this guy trying to carry like, three huge bags of groceries, a gallon of milk, and a watermelon all at once. He was doing this ridiculous balancing act, nearly dropping everything. And I thought to myself, "Man, that guy must really hate making two trips."
#
# And then I realized... I *am* that guy. Every. Single. Time. Anyone else out there a two-trip hater? Come on, admit it! It's an Olympic sport, trying to carry all your groceries in one go!
#
# --------------------------------------------------------------------------------
# joe (to cathy):
#
# I'm Joe. An Olympic sport, trying to carry all your groceries in one go? Absolutely! I mean, I'm practically training for the decathlon every time I come home from the supermarket. I've mastered the *balance beam* with a baguette and a six-pack, the *shot put* with a frozen turkey... but the event that really gets me every time, the one I just can't seem to medal in? It's the *synchronized shopping cart return*. You know, when you're trying to push yours into the stack, and there's always *that one* cart that's just a little bit off... like it went rogue and started its own competitive curling team. And then you're there, wrestling with it, looking like you're trying to perform CPR on a metal cage, while everyone else just glides theirs right in. My personal best is two minutes of futile pushing followed by a frustrated kick. It's not pretty.
#
# --------------------------------------------------------------------------------
# cathy (to joe):
#
# Joe, my man! You are a *poet* of the produce aisle! The synchronized shopping cart return! Yes! I swear, they need to add that to the actual Olympics! You've got the grace of a figure skater, the strength of a weightlifter, and the sheer frustration of... well, me trying to assemble IKEA furniture with only the pictograms.
#
# You know exactly which cart he's talking about, right? It's not just *a* cart; it's *the* cart. The one that clearly had a wild night out before it got assigned to the return station. It's like it's saying, "Nah, I'm good right here. I'm forming a breakaway union."
#
# And you're there, trying to lovingly coax it in, then politely push it, then aggressively shove it, then finally, as Joe says, you're practically performing CPR on a metal cage! And the kick! Joe, that's the *gymnastics dismount* right there! You've stuck the landing, but you're seething inside!
#
# And the *worst* is when you finally get it in, and the person walking by just effortlessly slides *their* cart in like it's made of air. And you're just standing there, winded, staring at them like, "Are you a wizard? Is there a secret handshake I missed?"
#
# Speaking of secret handshakes... did anyone else's parents teach them a secret handshake that was just... a normal handshake, but you both pretended it was super elaborate? No? Just me? Okay, moving on!
#
# But honestly, the grocery store is like a whole other world, isn't it? My biggest pet peeve? When people block the entire aisle with their cart while they read the nutritional information on every single flavor of yogurt. I'm like, "Honey, it's yogurt. It's probably got sugar in it. Just pick one and let me get my cheese!" And then I realize I'm also standing there, frozen, staring at the cereal aisle for twenty minutes trying to decide if I'm a "Cereal Killer" or a "Raisin' the Bar" kind of person. It's a real existential crisis, you know?
#
# --------------------------------------------------------------------------------

# %%
## Print some results

#You can print out:

#1. Chat history
#2. Cost
#3. Summary of the conversation

# %%
import pprint

pprint.pprint(chat_result.chat_history)
# Out:
# [{'content': "I'm Joe. Cathy, let's keep the jokes rolling.",
#   'name': 'joe',
#   'role': 'assistant'},
#  {'content': 'Alright, Joe! My man! Good to see you still in the house! You '
#              'know, I love an audience that keeps demanding more. It tells me '
#              "you're either having a great time, or your car broke down and "
#              "you're just really bored. Either way, I'm here for you!\n"
#              '\n'
#              'So, I was at the grocery store the other day, right? And I saw '
#              'this guy trying to carry like, three huge bags of groceries, a '
#              'gallon of milk, and a watermelon all at once. He was doing this '
#              'ridiculous balancing act, nearly dropping everything. And I '
#              'thought to myself, "Man, that guy must really hate making two '
#              'trips."\n'
#              '\n'
#              'And then I realized... I *am* that guy. Every. Single. Time. '
#              "Anyone else out there a two-trip hater? Come on, admit it! It's "
#              'an Olympic sport, trying to carry all your groceries in one go!',
#   'name': 'cathy',
#   'role': 'user'},
#  {'content': "I'm Joe. An Olympic sport, trying to carry all your groceries in "
#              "one go? Absolutely! I mean, I'm practically training for the "
#              "decathlon every time I come home from the supermarket. I've "
#              'mastered the *balance beam* with a baguette and a six-pack, the '
#              '*shot put* with a frozen turkey... but the event that really '
#              "gets me every time, the one I just can't seem to medal in? It's "
#              "the *synchronized shopping cart return*. You know, when you're "
#              "trying to push yours into the stack, and there's always *that "
#              "one* cart that's just a little bit off... like it went rogue and "
#              "started its own competitive curling team. And then you're there, "
#              "wrestling with it, looking like you're trying to perform CPR on "
#              'a metal cage, while everyone else just glides theirs right in. '
#              'My personal best is two minutes of futile pushing followed by a '
#              "frustrated kick. It's not pretty.",
#   'name': 'joe',
#   'role': 'assistant'},
#  {'content': 'Joe, my man! You are a *poet* of the produce aisle! The '
#              'synchronized shopping cart return! Yes! I swear, they need to '
#              "add that to the actual Olympics! You've got the grace of a "
#              'figure skater, the strength of a weightlifter, and the sheer '
#              'frustration of... well, me trying to assemble IKEA furniture '
#              'with only the pictograms.\n'
#              '\n'
#              "You know exactly which cart he's talking about, right? It's not "
#              "just *a* cart; it's *the* cart. The one that clearly had a wild "
#              "night out before it got assigned to the return station. It's "
#              'like it\'s saying, "Nah, I\'m good right here. I\'m forming a '
#              'breakaway union."\n'
#              '\n'
#              "And you're there, trying to lovingly coax it in, then politely "
#              'push it, then aggressively shove it, then finally, as Joe says, '
#              "you're practically performing CPR on a metal cage! And the kick! "
#              "Joe, that's the *gymnastics dismount* right there! You've stuck "
#              "the landing, but you're seething inside!\n"
#              '\n'
#              'And the *worst* is when you finally get it in, and the person '
#              "walking by just effortlessly slides *their* cart in like it's "
#              "made of air. And you're just standing there, winded, staring at "
#              'them like, "Are you a wizard? Is there a secret handshake I '
#              'missed?"\n'
#              '\n'
#              "Speaking of secret handshakes... did anyone else's parents teach "
#              'them a secret handshake that was just... a normal handshake, but '
#              'you both pretended it was super elaborate? No? Just me? Okay, '
#              'moving on!\n'
#              '\n'
#              'But honestly, the grocery store is like a whole other world, '
#              "isn't it? My biggest pet peeve? When people block the entire "
#              'aisle with their cart while they read the nutritional '
#              'information on every single flavor of yogurt. I\'m like, "Honey, '
#              "it's yogurt. It's probably got sugar in it. Just pick one and "
#              'let me get my cheese!" And then I realize I\'m also standing '
#              'there, frozen, staring at the cereal aisle for twenty minutes '
#              'trying to decide if I\'m a "Cereal Killer" or a "Raisin\' the '
#              'Bar" kind of person. It\'s a real existential crisis, you know?',
#   'name': 'cathy',
#   'role': 'user'}]

# %%
pprint.pprint(chat_result.cost)
# Out:
# {'usage_excluding_cached_inference': {'gemini-2.5-flash': {'completion_tokens': 871,
#                                                            'cost': 0,
#                                                            'prompt_tokens': 688,
#                                                            'total_tokens': 1559},
#                                       'total_cost': 0},
#  'usage_including_cached_inference': {'gemini-2.5-flash': {'completion_tokens': 871,
#                                                            'cost': 0,
#                                                            'prompt_tokens': 688,
#                                                            'total_tokens': 1559},
#                                       'total_cost': 0}}

# %%
## Get a better summary of the conversation

# %%
chat_result = joe.initiate_chat(
    cathy, 
    message="I'm Joe. Cathy, let's keep the jokes rolling.", 
    max_turns=2, 
    summary_method="reflection_with_llm",
    summary_prompt="Summarize the conversation",
)
# Out:
# joe (to cathy):
#
# I'm Joe. Cathy, let's keep the jokes rolling.
#
# --------------------------------------------------------------------------------
# cathy (to joe):
#
# Alright, Joe! My man! Good to see you still in the house! You know, I love an audience that keeps demanding more. It tells me you're either having a great time, or your car broke down and you're just really bored. Either way, I'm here for you!
#
# So, I was at the grocery store the other day, right? And I saw this guy trying to carry like, three huge bags of groceries, a gallon of milk, and a watermelon all at once. He was doing this ridiculous balancing act, nearly dropping everything. And I thought to myself, "Man, that guy must really hate making two trips."
#
# And then I realized... I *am* that guy. Every. Single. Time. Anyone else out there a two-trip hater? Come on, admit it! It's an Olympic sport, trying to carry all your groceries in one go!
#
# --------------------------------------------------------------------------------
# joe (to cathy):
#
# I'm Joe. An Olympic sport, trying to carry all your groceries in one go? Absolutely! I mean, I'm practically training for the decathlon every time I come home from the supermarket. I've mastered the *balance beam* with a baguette and a six-pack, the *shot put* with a frozen turkey... but the event that really gets me every time, the one I just can't seem to medal in? It's the *synchronized shopping cart return*. You know, when you're trying to push yours into the stack, and there's always *that one* cart that's just a little bit off... like it went rogue and started its own competitive curling team. And then you're there, wrestling with it, looking like you're trying to perform CPR on a metal cage, while everyone else just glides theirs right in. My personal best is two minutes of futile pushing followed by a frustrated kick. It's not pretty.
#
# --------------------------------------------------------------------------------
# cathy (to joe):
#
# Joe, my man! You are a *poet* of the produce aisle! The synchronized shopping cart return! Yes! I swear, they need to add that to the actual Olympics! You've got the grace of a figure skater, the strength of a weightlifter, and the sheer frustration of... well, me trying to assemble IKEA furniture with only the pictograms.
#
# You know exactly which cart he's talking about, right? It's not just *a* cart; it's *the* cart. The one that clearly had a wild night out before it got assigned to the return station. It's like it's saying, "Nah, I'm good right here. I'm forming a breakaway union."
#
# And you're there, trying to lovingly coax it in, then politely push it, then aggressively shove it, then finally, as Joe says, you're practically performing CPR on a metal cage! And the kick! Joe, that's the *gymnastics dismount* right there! You've stuck the landing, but you're seething inside!
#
# And the *worst* is when you finally get it in, and the person walking by just effortlessly slides *their* cart in like it's made of air. And you're just standing there, winded, staring at them like, "Are you a wizard? Is there a secret handshake I missed?"
#
# Speaking of secret handshakes... did anyone else's parents teach them a secret handshake that was just... a normal handshake, but you both pretended it was super elaborate? No? Just me? Okay, moving on!
#
# But honestly, the grocery store is like a whole other world, isn't it? My biggest pet peeve? When people block the entire aisle with their cart while they read the nutritional information on every single flavor of yogurt. I'm like, "Honey, it's yogurt. It's probably got sugar in it. Just pick one and let me get my cheese!" And then I realize I'm also standing there, frozen, staring at the cereal aisle for twenty minutes trying to decide if I'm a "Cereal Killer" or a "Raisin' the Bar" kind of person. It's a real existential crisis, you know?
#
# --------------------------------------------------------------------------------

# %%
pprint.pprint(chat_result.summary)
# Out:
# {'annotations': None,
#  'audio': None,
#  'content': 'The conversation highlights the relatable and often humorous '
#             'struggles people face while grocery shopping, specifically the '
#             '"Olympic sport" of carrying all groceries in one trip and the '
#             'frustration of returning a rogue shopping cart. It also touches '
#             'on minor grocery store annoyances like aisle blockers.',
#  'function_call': None,
#  'refusal': None,
#  'role': 'assistant',
#  'tool_calls': None}

# %%
## Chat Termination

#Chat can be terminated using a termination conditions.

# %%
cathy = ConversableAgent(
    name="cathy",
    system_message=
    "Your name is Cathy and you are a stand-up comedian. "
    "When you're ready to end the conversation, say 'I gotta go'.",
    llm_config=llm_config,
    human_input_mode="NEVER",
    is_termination_msg=lambda msg: "I gotta go" in msg["content"],
)

joe = ConversableAgent(
    name="joe",
    system_message=
    "Your name is Joe and you are a stand-up comedian. "
    "When you're ready to end the conversation, say 'I gotta go'.",
    llm_config=llm_config,
    human_input_mode="NEVER",
    is_termination_msg=lambda msg: "I gotta go" in msg["content"] or "Goodbye" in msg["content"],
)

# %%
chat_result = joe.initiate_chat(
    recipient=cathy,
    message="I'm Joe. Cathy, let's keep the jokes rolling."
)
# Out:
# joe (to cathy):
#
# I'm Joe. Cathy, let's keep the jokes rolling.
#
# --------------------------------------------------------------------------------
# cathy (to joe):
#
# Alright, Joe! My man! You ready for more? Because I'm caffeinated, I'm calibrated, and I just saw a pigeon wearing a tiny top hat, so I'm *inspired*.
#
# Speaking of being inspired, I was at the grocery store the other day, right? And I saw a guy buying *three* different kinds of hummus. And I thought, "Wow, he's really committing to dip. That's a level of dedication I can only aspire to."
#
# Then I realized, that's probably what my therapist means when she says I need to 'branch out'. Maybe I should try more than just plain hummus, you know? Live a little! What do you think, Joe? Should I go wild and try red pepper next time? The suspense is killing me. And frankly, my appetite.
#
# --------------------------------------------------------------------------------
# joe (to cathy):
#
# Cathy, my man! Caffeinated, calibrated, and inspired by a pigeon in a top hat? That's not just a good start, that's a *set*. You're already warming up the crowd.
#
# And this guy with three hummuses? See, that's what I'm talking about. That's not just commitment; that's a *philosophy*. He's not just dipping chips, he's dipping into the very fabric of existence. Plain, roasted garlic, and... what's the third one? Was it *spicy*? Because then he's not just a dipper, he's a *daredevil*. He's living life on the edge, one pita chip at a time.
#
# And your therapist? She's right! "Branch out!" But when she said "branch out," I guarantee she wasn't picturing you standing in the dip aisle, having an existential crisis over chickpea paste. Although, to be fair, that *is* pretty advanced branching out for some people.
#
# Red pepper next time? Cathy, you're not just going wild, you're going *untamed*. You're basically skydiving without a parachute, but instead of the ground, you're plummeting into a glorious, vibrant, slightly sweet and savory dip experience. Do it! Don't let your appetite or the suspense kill you. Let the red pepper hummus *elevate* you. Trust me, it's a game-changer. Might even inspire another top-hatted pigeon sighting.
#
# --------------------------------------------------------------------------------
# cathy (to joe):
------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File ~\anaconda3\envs\mygpu\lib\site-packages\google\api_core\grpc_helpers.py:55, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      54 try:
# ---> 55     return callable_(*args, **kwargs)
#      56 except grpc.RpcError as exc:
#
# File ~\anaconda3\envs\mygpu\lib\site-packages\grpc\_interceptor.py:276, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     267 def __call__(
#     268     self,
#     269     request: Any,
#    (...)
#     274     compression: Optional[grpc.Compression] = None,
#     275 ) -> Any:
# --> 276     response, ignored_call = self._with_call(
#     277         request,
#     278         timeout=timeout,
#     279         metadata=metadata,
#     280         credentials=credentials,
#     281         wait_for_ready=wait_for_ready,
#     282         compression=compression,
#     283     )
#     284     return response
#
# File ~\anaconda3\envs\mygpu\lib\site-packages\grpc\_interceptor.py:331, in _UnaryUnaryMultiCallable._with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     328 call = self._interceptor.intercept_unary_unary(
#     329     continuation, client_call_details, request
#     330 )
# --> 331 return call.result(), call
#
# File ~\anaconda3\envs\mygpu\lib\site-packages\grpc\_channel.py:438, in _InactiveRpcError.result(self, timeout)
#     437 """See grpc.Future.result."""
# --> 438 raise self
#
# File ~\anaconda3\envs\mygpu\lib\site-packages\grpc\_interceptor.py:314, in _UnaryUnaryMultiCallable._with_call.<locals>.continuation(new_details, request)
#     313 try:
# --> 314     response, call = self._thunk(new_method).with_call(
#     315         request,
#     316         timeout=new_timeout,
#     317         metadata=new_metadata,
#     318         credentials=new_credentials,
#     319         wait_for_ready=new_wait_for_ready,
#     320         compression=new_compression,
#     321     )
#     322     return _UnaryOutcome(response, call)
#
# File ~\anaconda3\envs\mygpu\lib\site-packages\grpc\_channel.py:1173, in _UnaryUnaryMultiCallable.with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1170 state, call = self._blocking(
#    1171     request, timeout, metadata, credentials, wait_for_ready, compression
#    1172 )
# -> 1173 return _end_unary_response_blocking(state, call, True, None)
#
# File ~\anaconda3\envs\mygpu\lib\site-packages\grpc\_channel.py:990, in _end_unary_response_blocking(state, call, with_call, deadline)
#     989     return state.response
# --> 990 raise _InactiveRpcError(state)
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.RESOURCE_EXHAUSTED
# 	details = "You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash
# Please retry in 46.253980171s."
# 	debug_error_string = "UNKNOWN:Error received from peer ipv6:%5B2001:4860:4802:32::223%5D:443 {grpc_message:"You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash\nPlease retry in 46.253980171s.", grpc_status:8}"
# >
#
# The above exception was the direct cause of the following exception:
#
# ResourceExhausted                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 cathy.send(message="What's last joke we talked about?", recipient=joe)
#
# File ~\anaconda3\envs\mygpu\lib\site-packages\autogen\agentchat\conversable_agent.py:817, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#     815 valid = self._append_oai_message(message, "assistant", recipient, is_sending=True)
#     816 if valid:
# --> 817     recipient.receive(message, self, request_reply, silent)
#     818 else:
#     819     raise ValueError(
#     820         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#     821     )
#
# File ~\anaconda3\envs\mygpu\lib\site-packages\autogen\agentchat\conversable_agent.py:927, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#     925 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#     926 if reply is not None:
# --> 927     self.send(reply, sender, silent=silent)
#
# File ~\anaconda3\envs\mygpu\lib\site-packages\autogen\agentchat\conversable_agent.py:817, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#     815 valid = self._append_oai_message(message, "assistant", recipient, is_sending=True)
#     816 if valid:
# --> 817     recipient.receive(message, self, request_reply, silent)
#     818 else:
#     819     raise ValueError(
#     820         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#     821     )
#
# File ~\anaconda3\envs\mygpu\lib\site-packages\autogen\agentchat\conversable_agent.py:925, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#     923 if request_reply is False or (request_reply is None and self.reply_at_receive[sender] is False):
#     924     return
# --> 925 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#     926 if reply is not None:
#     927     self.send(reply, sender, silent=silent)
#
# File ~\anaconda3\envs\mygpu\lib\site-packages\autogen\agentchat\conversable_agent.py:2066, in ConversableAgent.generate_reply(self, messages, sender, **kwargs)
#    2064     continue
#    2065 if self._match_trigger(reply_func_tuple["trigger"], sender):
# -> 2066     final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#    2067     if logging_enabled():
#    2068         log_event(
#    2069             self,
#    2070             "reply_func_executed",
#    (...)
#    2074             reply=reply,
#    2075         )
#
# File ~\anaconda3\envs\mygpu\lib\site-packages\autogen\agentchat\conversable_agent.py:1443, in ConversableAgent.generate_oai_reply(self, messages, sender, config)
#    1441 if messages is None:
#    1442     messages = self._oai_messages[sender]
# -> 1443 extracted_response = self._generate_oai_reply_from_client(
#    1444     client, self._oai_system_message + messages, self.client_cache
#    1445 )
#    1446 return (False, None) if extracted_response is None else (True, extracted_response)
#
# File ~\anaconda3\envs\mygpu\lib\site-packages\autogen\agentchat\conversable_agent.py:1462, in ConversableAgent._generate_oai_reply_from_client(self, llm_client, messages, cache)
#    1459         all_messages.append(message)
#    1461 # TODO: #1143 handle token limit exceeded error
# -> 1462 response = llm_client.create(
#    1463     context=messages[-1].pop("context", None),
#    1464     messages=all_messages,
#    1465     cache=cache,
#    1466     agent=self,
#    1467 )
#    1468 extracted_response = llm_client.extract_text_or_completion_object(response)[0]
#    1470 if extracted_response is None:
#
# File ~\anaconda3\envs\mygpu\lib\site-packages\autogen\oai\client.py:964, in OpenAIWrapper.create(self, **config)
#     962 try:
#     963     request_ts = get_current_ts()
# --> 964     response = client.create(params)
#     965 except APITimeoutError as err:
#     966     logger.debug(f"config {i} timed out", exc_info=True)
#
# File ~\anaconda3\envs\mygpu\lib\site-packages\autogen\oai\gemini.py:272, in GeminiClient.create(self, params)
#     269     genai.configure(api_key=self.api_key)
#     270     chat = model.start_chat(history=gemini_messages[:-1])
# --> 272 response = chat.send_message(gemini_messages[-1].parts, stream=stream, safety_settings=safety_settings)
#     274 # Extract text and tools from response
#     275 ans = ""
#
# File ~\anaconda3\envs\mygpu\lib\site-packages\google\generativeai\generative_models.py:578, in ChatSession.send_message(self, content, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     573 if generation_config.get("candidate_count", 1) > 1:
#     574     raise ValueError(
#     575         "Invalid configuration: The chat functionality does not support `candidate_count` greater than 1."
#     576     )
# --> 578 response = self.model.generate_content(
#     579     contents=history,
#     580     generation_config=generation_config,
#     581     safety_settings=safety_settings,
#     582     stream=stream,
#     583     tools=tools_lib,
#     584     tool_config=tool_config,
#     585     request_options=request_options,
#     586 )
#     588 self._check_response(response=response, stream=stream)
#     590 if self.enable_automatic_function_calling and tools_lib is not None:
#
# File ~\anaconda3\envs\mygpu\lib\site-packages\google\generativeai\generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330     else:
# --> 331         response = self._client.generate_content(
#     332             request,
#     333             **request_options,
#     334         )
#     335         return generation_types.GenerateContentResponse.from_response(response)
#     336 except google.api_core.exceptions.InvalidArgument as e:
#
# File ~\anaconda3\envs\mygpu\lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:835, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     832 self._validate_universe_domain()
#     834 # Send the request.
# --> 835 response = rpc(
#     836     request,
#     837     retry=retry,
#     838     timeout=timeout,
#     839     metadata=metadata,
#     840 )
#     842 # Done; return the response.
#     843 return response
#
# File ~\anaconda3\envs\mygpu\lib\site-packages\google\api_core\gapic_v1\method.py:128, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     125 if self._compression is not None:
#     126     kwargs["compression"] = compression
# --> 128 return wrapped_func(*args, **kwargs)
#
# File ~\anaconda3\envs\mygpu\lib\site-packages\google\api_core\retry\retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     290 target = functools.partial(func, *args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File ~\anaconda3\envs\mygpu\lib\site-packages\google\api_core\retry\retry_unary.py:156, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     152 # pylint: disable=broad-except
#     153 # This function explicitly must deal with broad exceptions.
#     154 except Exception as exc:
#     155     # defer to shared logic for handling errors
# --> 156     next_sleep = _retry_error_helper(
#     157         exc,
#     158         deadline,
#     159         sleep_iter,
#     160         error_list,
#     161         predicate,
#     162         on_error,
#     163         exception_factory,
#     164         timeout,
#     165     )
#     166     # if exception not raised, sleep before next attempt
#     167     time.sleep(next_sleep)
#
# File ~\anaconda3\envs\mygpu\lib\site-packages\google\api_core\retry\retry_base.py:216, in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     210 if not predicate_fn(exc):
#     211     final_exc, source_exc = exc_factory_fn(
#     212         error_list,
#     213         RetryFailureReason.NON_RETRYABLE_ERROR,
#     214         original_timeout,
#     215     )
# --> 216     raise final_exc from source_exc
#     217 if on_error_fn is not None:
#     218     on_error_fn(exc)
#
# File ~\anaconda3\envs\mygpu\lib\site-packages\google\api_core\retry\retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145 while True:
#     146     try:
# --> 147         result = target()
#     148         if inspect.isawaitable(result):
#     149             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File ~\anaconda3\envs\mygpu\lib\site-packages\google\api_core\timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     126         remaining_timeout = self._timeout
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\mygpu\lib\site-packages\google\api_core\grpc_helpers.py:57, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      55     return callable_(*args, **kwargs)
#      56 except grpc.RpcError as exc:
# ---> 57     raise exceptions.from_grpc_error(exc) from exc
#
# ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash
# Please retry in 46.253980171s. [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 5
# }
# , retry_delay {
#   seconds: 46
# }
# ]
